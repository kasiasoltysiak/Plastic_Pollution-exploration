# %% [markdown]
# <h1>Nike fabrics used</h1>
#
# <h2>Objective</h2>
#
# Analyze the types and volumes of materials used by Nike, focusing on sustainability and trends.

# %% [markdown]
# <h2>Steps</h2>
# - Load and Inspect Data
# - Ensure the data is clean (e.g., no missing values, consistent formatting) </br>
# - Identify key columns like material type, volume (in tonnes), and year.</br>
# - Aggregate Data by Material Type:</br>
# - Calculate the total volume for each type of fabric across all years.</br>
# - Rank materials by their volume contribution.</br>
# - Analyze Sustainability Trends:</br>
# - Focus on recycled materials (e.g., recycled polyester, recycled rubber) and their share of total material use.</br>
# - Compute and visualize the percentage of recycled vs. non-recycled materials per year.</br>
# - Visualize Trends:</br>
# - Create line charts for the volumes of each material over time.</br>
# - Use stacked bar charts to show the proportion of recycled materials in total use per year.</br>
# - Highlight Insights:</br>
# - Discuss whether Nike is moving towards more sustainable practices based on the data.</br>
# - Identify materials that dominate the product line and their environmental implications.

# %%
import pandas as pd

# Data dictionary
data = {
    "Material": [
        "Polyester Recycled", "Total Polyester Use",
        "Cotton Organic", "Cotton Recycled", "Cotton Third-Party Certified", "Total Cotton Use",
        "Rubber Recycled", "Total Rubber Use",
        "EVA Foam Recycled", "Total EVA Foam Use",
        "Leather Flyleather", "Leather Synthetic Leather", "Total Leather Use"
    ],
    "FY20 Metric Tons": [44387, 195490, 10811, 503, 85139, 113615, 564, 76141, 978, 61053, 53, 18623, 51646],
    "FY20 %": [23, None, 10, 0.4, 75, None, 0.7, None, 2, None, 0.1, 36, None],
    "FY21 Metric Tons": [55477, 166343, 13680, 905, 66776, 115543, 689, 78896, 907, 53055, 57, 16031, 60502],
    "FY21 %": [33, None, 12, 0.8, 58, None, 0.9, None, 2, None, 0.1, 26, None],
    "FY22 Metric Tons": [82317, 180645, 17748, 867, 94417, 142113, 2045, 94494, 2648, 44523, 13, 18117, 65870],
    "FY22 %": [46, None, 12, 0.6, 66, None, 2, None, 0.1, None, 0.02, 28, None],
}

# Convert to DataFrame
nike_data = pd.DataFrame(data)

nike_data
# Out:
#                         Material  FY20 Metric Tons  FY20 %  FY21 Metric Tons  \
# 0             Polyester Recycled             44387    23.0             55477
# 1            Total Polyester Use            195490     NaN            166343
# 2                 Cotton Organic             10811    10.0             13680
# 3                Cotton Recycled               503     0.4               905
# 4   Cotton Third-Party Certified             85139    75.0             66776
# 5               Total Cotton Use            113615     NaN            115543
# 6                Rubber Recycled               564     0.7               689
# 7               Total Rubber Use             76141     NaN             78896
# 8              EVA Foam Recycled               978     2.0               907
# 9             Total EVA Foam Use             61053     NaN             53055
# 10            Leather Flyleather                53     0.1                57
# 11     Leather Synthetic Leather             18623    36.0             16031
# 12             Total Leather Use             51646     NaN             60502
#
#     FY21 %  FY22 Metric Tons  FY22 %
# 0     33.0             82317   46.00
# 1      NaN            180645     NaN
# 2     12.0             17748   12.00
# 3      0.8               867    0.60
# 4     58.0             94417   66.00
# 5      NaN            142113     NaN
# 6      0.9              2045    2.00
# 7      NaN             94494     NaN
# 8      2.0              2648    0.10
# 9      NaN             44523     NaN
# 10     0.1                13    0.02
# 11    26.0             18117   28.00
# 12     NaN             65870     NaN

# %%
nike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Material          13 non-null     object
#  1   FY20 Metric Tons  13 non-null     int64
#  2   FY20 %            8 non-null      float64
#  3   FY21 Metric Tons  13 non-null     int64
#  4   FY21 %            8 non-null      float64
#  5   FY22 Metric Tons  13 non-null     int64
#  6   FY22 %            8 non-null      float64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 860.0+ bytes

# %%
nike_data.describe()
# Out:
#        FY20 Metric Tons     FY20 %  FY21 Metric Tons     FY21 %  \
# count         13.000000   8.000000         13.000000   8.000000
# mean       50692.538462  18.400000      48373.923077  16.600000
# std        57441.624531  26.311812      51057.643415  20.955667
# min           53.000000   0.100000         57.000000   0.100000
# 25%          978.000000   0.625000        907.000000   0.875000
# 50%        44387.000000   6.000000      53055.000000   7.000000
# 75%        76141.000000  26.250000      66776.000000  27.750000
# max       195490.000000  75.000000     166343.000000  58.000000
#
#        FY22 Metric Tons     FY22 %
# count         13.000000   8.000000
# mean       57370.538462  19.340000
# std        58904.505864  25.105735
# min           13.000000   0.020000
# 25%         2648.000000   0.475000
# 50%        44523.000000   7.000000
# 75%        94417.000000  32.500000
# max       180645.000000  66.000000

# %% [markdown]
# From here we see that polyester is the main fabric used by Nike

# %%
#Let's see totals: for this, we need to make a df with rows containing 'total' only
nike_totals = nike_data[nike_data['Material'].str.contains('total', case=False, na=False)]
nike_totals
# Out:
#                Material  FY20 Metric Tons  FY20 %  FY21 Metric Tons  FY21 %  \
# 1   Total Polyester Use            195490     NaN            166343     NaN
# 5      Total Cotton Use            113615     NaN            115543     NaN
# 7      Total Rubber Use             76141     NaN             78896     NaN
# 9    Total EVA Foam Use             61053     NaN             53055     NaN
# 12    Total Leather Use             51646     NaN             60502     NaN
#
#     FY22 Metric Tons  FY22 %
# 1             180645     NaN
# 5             142113     NaN
# 7              94494     NaN
# 9              44523     NaN
# 12             65870     NaN

# %%
#stack bar for each fabric
import matplotlib.pyplot as plt

# Plot stacked bar chart for all fabric types
fig, ax = plt.subplots(figsize=(10, 6))

# Plotting a stacked bar plot for each year (FY20, FY21, FY22)
nike_totals[['FY20 Metric Tons', 'FY21 Metric Tons', 'FY22 Metric Tons']].plot(kind='bar', stacked=True, ax=ax)

# Adding labels and title
ax.set_xlabel('Fabric Type')
ax.set_ylabel('Metric Tons')
ax.set_title('Fabric Use by Year for Nike')

# Show the plot
plt.tight_layout()
plt.show()

# %%
nike_totals.drop(['FY20 %', 'FY21 %', 'FY22 %'], axis=1, inplace=True)
# Out:
# /var/folders/p8/tf6kcfpn4z9gn1_6rjv2qlp00000gn/T/ipykernel_64168/2206599740.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nike_totals.drop(['FY20 %', 'FY21 %', 'FY22 %'], axis=1, inplace=True)

# %%
column_sums = nike_totals[['FY20 Metric Tons','FY21 Metric Tons','FY22 Metric Tons']].sum()
print(column_sums)
# Out:
# FY20 Metric Tons    497945
# FY21 Metric Tons    474339
# FY22 Metric Tons    527645
# dtype: int64

# %%
#nike_totals.reset_index(inplace=True)
#nike_totals

# %%
#nike_totals = pd.concat([nike_totals, total_volumes], ignore_index=True)
#nike_totals

# %%
nike_totals.set_index(['Material'], inplace=True)
nike_totals
# Out:
#                      FY20 Metric Tons  FY21 Metric Tons  FY22 Metric Tons
# Material
# Total Polyester Use            195490            166343            180645
# Total Cotton Use               113615            115543            142113
# Total Rubber Use                76141             78896             94494
# Total EVA Foam Use              61053             53055             44523
# Total Leather Use               51646             60502             65870

# %%
nike_totals_pivot=nike_totals.T
nike_totals_pivot
# Out:
# Material          Total Polyester Use  Total Cotton Use  Total Rubber Use  \
# FY20 Metric Tons               195490            113615             76141
# FY21 Metric Tons               166343            115543             78896
# FY22 Metric Tons               180645            142113             94494
#
# Material          Total EVA Foam Use  Total Leather Use
# FY20 Metric Tons               61053              51646
# FY21 Metric Tons               53055              60502
# FY22 Metric Tons               44523              65870

# %%
# Plot stacked bar chart for all fabric types
fig, ax = plt.subplots(figsize=(10, 6))

# Plotting a stacked bar plot for each year (FY20, FY21, FY22)
nike_totals_pivot[['Total Polyester Use', 'Total Cotton Use','Total Rubber Use','Total EVA Foam Use','Total Leather Use']].plot(kind='bar', stacked=True, ax=ax)

# Adding labels and title
ax.set_xlabel('Fabric Type')
ax.set_ylabel('Metric Tons')
ax.set_title('Fabric Use by Year for Nike')

# Show the plot
plt.tight_layout()
plt.show()

#change the legend outside, change colurs, labels, names inside
